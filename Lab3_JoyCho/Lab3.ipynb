# %% [markdown]
# # Jupyter Notebook CPU Monitoring

# %%
import os
import time

# %%
print("Running on either CPUs")
os.system("python3 fib.py")

time.sleep(5)

print("Running on CPU1")
os.system("taskset -c 1 python3 fib.py")
# Out:
# Running on either CPUs
# time spent: 12.518228530883789
# Running on CPU1
# time spent: 12.228475093841553
# 0
